# %%
#Import Libraries and Files
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

file = "/Users/juliarivera/Desktop/itmgt25/transaction-data-adhoc-analysis.json"

df_1 = pd.read_json(file)
df_1
# Out:
#                                                  address   birthdate  \
# 0                              USNS Wagner\nFPO AE 00917  1926/03/11
# 1                             USCGC Benson\nFPO AP 48794  2016/07/08
# 2                             USCGC Benson\nFPO AP 48794  2016/07/08
# 3                             USCGC Benson\nFPO AP 48794  2016/07/08
# 4               33911 Hansen Loaf\nWest Sandra, ND 54188  1949/09/27
# ...                                                  ...         ...
# 83031      96081 Harrison Brooks\nJenniferbury, MA 02124  2019/10/26
# 83032  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83033  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83034  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 83035                   PSC 1089, Box 3720\nAPO AE 08973  2012/04/30
#
#                             mail               name sex       username  \
# 0         watsonbrenda@gmail.com  Jennifer Campbell   F  veronicawells
# 1            moorelisa@gmail.com        Melissa Kim   F       cgilbert
# 2            moorelisa@gmail.com        Melissa Kim   F       cgilbert
# 3            moorelisa@gmail.com        Melissa Kim   F       cgilbert
# 4            michael78@yahoo.com     Kristen Cooper   F     qhernandez
# ...                          ...                ...  ..            ...
# 83031    christina55@hotmail.com         Tammy Byrd   F     kmcconnell
# 83032  melvinschmidt@hotmail.com    Donald Andersen   M          llowe
# 83033  melvinschmidt@hotmail.com    Donald Andersen   M          llowe
# 83034  melvinschmidt@hotmail.com    Donald Andersen   M          llowe
# 83035         xjones@hotmail.com  Stephanie Russell   F      cmcdowell
#
#                                        transaction_items  transaction_value  \
# 0                      Exotic Extras,Beef Chicharon,(x4)               5196
# 1      Exotic Extras,Beef Chicharon,(x3);HealthyKid 3...              12056
# 2      HealthyKid 3+,Gummy Vitamins,(x3);HealthyKid 3...               5500
# 3                    HealthyKid 3+,Yummy Vegetables,(x1)                500
# 4      Candy City,Orange Beans,(x3);Candy City,Gummy ...               2697
# ...                                                  ...                ...
# 83031  Exotic Extras,Kimchi and Seaweed,(x2);HealthyK...               3588
# 83032  HealthyKid 3+,Yummy Vegetables,(x1);Exotic Ext...               2095
# 83033  Candy City,Orange Beans,(x4);Candy City,Gummy ...               3396
# 83034  HealthyKid 3+,Nutrional Milk,(x2);Candy City,G...               4280
# 83035  HealthyKid 3+,Nutrional Milk,(x1);Candy City,G...               2639
#
#       transaction_date
# 0           2022/01/12
# 1           2022/01/12
# 2           2022/01/08
# 3           2022/01/10
# 4           2022/01/24
# ...                ...
# 83031       2022/06/05
# 83032       2022/06/12
# 83033       2022/06/15
# 83034       2022/06/09
# 83035       2022/06/03
#
# [83036 rows x 9 columns]

# %%
# Pivot Table (Sales per month, sale value per item per month)

# %%
#Clean data
import string
df_p = df_1.copy()
df_p_2 = df_p.transaction_items.str.split(";")
df_p = df_p.assign(transaction_items=df_p_2)
df_p = df_p[df_p["transaction_items"].apply(len)==1]
df_p['transaction_items'] = [','.join(map(str, l)) for l in df_p['transaction_items']]
df_p['quantities'] = df_p["transaction_items"].str[-5:]
df_p['quantities'] = df_p["quantities"].str.strip(',)(x')
df_p["quantities"] = df_p["quantities"].astype(int)
df_p["transaction_items"] = df_p["transaction_items"].str[:-5]

df_p
# Out:
#                                                  address   birthdate  \
# 0                              USNS Wagner\nFPO AE 00917  1926/03/11
# 3                             USCGC Benson\nFPO AP 48794  2016/07/08
# 6                                 USS Ware\nFPO AA 66840  1982/12/06
# 8      63261 Brewer Drive Apt. 704\nLake Alicia, NJ 0...  1956/08/27
# 11              2049 Schneider Walk\nScottfurt, DC 18004  1993/10/21
# ...                                                  ...         ...
# 83014  6047 Kelly Parkways Suite 417\nAdamsberg, DE 7...  1950/05/22
# 83017     1783 Snyder Plaza\nMontgomerychester, DC 09252  2022/01/27
# 83019  5868 Sloan Springs Suite 982\nRobinsonmouth, O...  1992/12/26
# 83024          31450 Perez Burgs\nWest Douglas, KS 03442  1946/10/26
# 83025       84708 Mitchell Road\nWest Jonathan, AL 22460  2016/01/05
#
#                          mail               name sex         username  \
# 0      watsonbrenda@gmail.com  Jennifer Campbell   F    veronicawells
# 3         moorelisa@gmail.com        Melissa Kim   F         cgilbert
# 6          pestrada@gmail.com       Michael Lowe   M      richardhays
# 8        racheldiaz@gmail.com  Jennifer Figueroa   F        hoodbrett
# 11        codydavis@gmail.com       Steven Woods   M       amandahill
# ...                       ...                ...  ..              ...
# 83014    angela20@hotmail.com       Bryan Kelley   M         joshua80
# 83017  powellkirk@hotmail.com         Mark Young   M        spencer43
# 83019    careyjason@gmail.com   Kathryn Cisneros   F      gregorywest
# 83024     tyler82@hotmail.com       Caleb Vaughn   M      troyedwards
# 83025      bsmith@hotmail.com    Shirley Everett   F  samanthadelgado
#
#                       transaction_items  transaction_value transaction_date  \
# 0          Exotic Extras,Beef Chicharon               5196       2022/01/12
# 3        HealthyKid 3+,Yummy Vegetables                500       2022/01/10
# 6      Exotic Extras,Kimchi and Seaweed               3196       2022/01/20
# 8                Candy City,Gummy Worms                150       2022/01/11
# 11         HealthyKid 3+,Gummy Vitamins               3000       2022/01/01
# ...                                 ...                ...              ...
# 83014      HealthyKid 3+,Nutrional Milk               7960       2022/06/29
# 83017      HealthyKid 3+,Nutrional Milk               1990       2022/06/11
# 83019           Candy City,Orange Beans                199       2022/06/26
# 83024      Exotic Extras,Beef Chicharon               3897       2022/06/28
# 83025      Exotic Extras,Beef Chicharon               5196       2022/06/29
#
#        quantities
# 0               4
# 3               1
# 6               4
# 8               1
# 11              2
# ...           ...
# 83014           4
# 83017           1
# 83019           1
# 83024           3
# 83025           4
#
# [27599 rows x 10 columns]

# %%
items = df_p[["transaction_items", "quantities", "transaction_value"]]
items = items.drop_duplicates(subset = "transaction_items", keep = "first")
index = list(items["transaction_items"].values)
index1 = set(items["transaction_items"])
#index1
items = items['transaction_value'] / items['quantities']
items.index = index
items
# Out:
# Exotic Extras,Beef Chicharon        1299.0
# HealthyKid 3+,Yummy Vegetables       500.0
# Exotic Extras,Kimchi and Seaweed     799.0
# Candy City,Gummy Worms               150.0
# HealthyKid 3+,Gummy Vitamins        1500.0
# HealthyKid 3+,Nutrional Milk        1990.0
# Candy City,Orange Beans              199.0
# dtype: float64

# %%
df_2 = df_1.assign(transaction_items=df_1.transaction_items.str.split(";")).explode('transaction_items').reset_index(drop=True)
#df_2['transaction_items'] = [','.join(map(str, l)) for l in df_2['transaction_items']]
df_2['quantities'] = df_2["transaction_items"].str[-5:]
df_2['quantities'] = df_2["quantities"].str.strip(',)(x')
df_2["quantities"] = df_2["quantities"].astype(int)
df_2["transaction_items"] = df_2["transaction_items"].str[:-5]
df_2["Total Sales"] = df_2["quantities"] * df_2["transaction_items"].apply(lambda x: items.loc[x])
df_2["Month"] = df_2["transaction_date"].str[6:7]
df_2
# Out:
#                                                   address   birthdate  \
# 0                               USNS Wagner\nFPO AE 00917  1926/03/11
# 1                              USCGC Benson\nFPO AP 48794  2016/07/08
# 2                              USCGC Benson\nFPO AP 48794  2016/07/08
# 3                              USCGC Benson\nFPO AP 48794  2016/07/08
# 4                              USCGC Benson\nFPO AP 48794  2016/07/08
# ...                                                   ...         ...
# 166114  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 166115  428 Kristopher Curve Apt. 206\nMcculloughville...  1913/11/04
# 166116                   PSC 1089, Box 3720\nAPO AE 08973  2012/04/30
# 166117                   PSC 1089, Box 3720\nAPO AE 08973  2012/04/30
# 166118                   PSC 1089, Box 3720\nAPO AE 08973  2012/04/30
#
#                              mail               name sex       username  \
# 0          watsonbrenda@gmail.com  Jennifer Campbell   F  veronicawells
# 1             moorelisa@gmail.com        Melissa Kim   F       cgilbert
# 2             moorelisa@gmail.com        Melissa Kim   F       cgilbert
# 3             moorelisa@gmail.com        Melissa Kim   F       cgilbert
# 4             moorelisa@gmail.com        Melissa Kim   F       cgilbert
# ...                           ...                ...  ..            ...
# 166114  melvinschmidt@hotmail.com    Donald Andersen   M          llowe
# 166115  melvinschmidt@hotmail.com    Donald Andersen   M          llowe
# 166116         xjones@hotmail.com  Stephanie Russell   F      cmcdowell
# 166117         xjones@hotmail.com  Stephanie Russell   F      cmcdowell
# 166118         xjones@hotmail.com  Stephanie Russell   F      cmcdowell
#
#                    transaction_items  transaction_value transaction_date  \
# 0       Exotic Extras,Beef Chicharon               5196       2022/01/12
# 1       Exotic Extras,Beef Chicharon              12056       2022/01/12
# 2       HealthyKid 3+,Nutrional Milk              12056       2022/01/12
# 3            Candy City,Orange Beans              12056       2022/01/12
# 4       HealthyKid 3+,Gummy Vitamins               5500       2022/01/08
# ...                              ...                ...              ...
# 166114  HealthyKid 3+,Nutrional Milk               4280       2022/06/09
# 166115        Candy City,Gummy Worms               4280       2022/06/09
# 166116  HealthyKid 3+,Nutrional Milk               2639       2022/06/03
# 166117        Candy City,Gummy Worms               2639       2022/06/03
# 166118       Candy City,Orange Beans               2639       2022/06/03
#
#         quantities  Total Sales Month
# 0                4       5196.0     1
# 1                3       3897.0     1
# 2                4       7960.0     1
# 3                1        199.0     1
# 4                3       4500.0     1
# ...            ...          ...   ...
# 166114           2       3980.0     6
# 166115           2        300.0     6
# 166116           1       1990.0     6
# 166117           3        450.0     6
# 166118           1        199.0     6
#
# [166119 rows x 12 columns]

# %%
#Pivot Table
df_pivot = df_2[['Total Sales','quantities']].groupby([df_2.transaction_items, df_2.Month]).agg(sum)
df_pivot_2 = df_pivot.reset_index()

df_pivot_2
# Out:
#                    transaction_items Month  Total Sales  quantities
# 0             Candy City,Gummy Worms     1    1433850.0        9559
# 1             Candy City,Gummy Worms     2    1499400.0        9996
# 2             Candy City,Gummy Worms     3    1497900.0        9986
# 3             Candy City,Gummy Worms     4    1506450.0       10043
# 4             Candy City,Gummy Worms     5    1470150.0        9801
# 5             Candy City,Gummy Worms     6    1490100.0        9934
# 6            Candy City,Orange Beans     1    1945026.0        9774
# 7            Candy City,Orange Beans     2    1997363.0       10037
# 8            Candy City,Orange Beans     3    1912589.0        9611
# 9            Candy City,Orange Beans     4    1972886.0        9914
# 10           Candy City,Orange Beans     5    1982836.0        9964
# 11           Candy City,Orange Beans     6    2011094.0       10106
# 12      Exotic Extras,Beef Chicharon     1   12554835.0        9665
# 13      Exotic Extras,Beef Chicharon     2   12991299.0       10001
# 14      Exotic Extras,Beef Chicharon     3   12750984.0        9816
# 15      Exotic Extras,Beef Chicharon     4   12847110.0        9890
# 16      Exotic Extras,Beef Chicharon     5   13026372.0       10028
# 17      Exotic Extras,Beef Chicharon     6   12862698.0        9902
# 18  Exotic Extras,Kimchi and Seaweed     1    7731124.0        9676
# 19  Exotic Extras,Kimchi and Seaweed     2    7949251.0        9949
# 20  Exotic Extras,Kimchi and Seaweed     3    7963633.0        9967
# 21  Exotic Extras,Kimchi and Seaweed     4    7926879.0        9921
# 22  Exotic Extras,Kimchi and Seaweed     5    7808627.0        9773
# 23  Exotic Extras,Kimchi and Seaweed     6    8073096.0       10104
# 24      HealthyKid 3+,Gummy Vitamins     1   14521500.0        9681
# 25      HealthyKid 3+,Gummy Vitamins     2   14970000.0        9980
# 26      HealthyKid 3+,Gummy Vitamins     3   15217500.0       10145
# 27      HealthyKid 3+,Gummy Vitamins     4   14763000.0        9842
# 28      HealthyKid 3+,Gummy Vitamins     5   14922000.0        9948
# 29      HealthyKid 3+,Gummy Vitamins     6   14970000.0        9980
# 30      HealthyKid 3+,Nutrional Milk     1   19356730.0        9727
# 31      HealthyKid 3+,Nutrional Milk     2   19285090.0        9691
# 32      HealthyKid 3+,Nutrional Milk     3   19653240.0        9876
# 33      HealthyKid 3+,Nutrional Milk     4   19474140.0        9786
# 34      HealthyKid 3+,Nutrional Milk     5   19663190.0        9881
# 35      HealthyKid 3+,Nutrional Milk     6   19436330.0        9767
# 36    HealthyKid 3+,Yummy Vegetables     1    4979500.0        9959
# 37    HealthyKid 3+,Yummy Vegetables     2    5128000.0       10256
# 38    HealthyKid 3+,Yummy Vegetables     3    4948000.0        9896
# 39    HealthyKid 3+,Yummy Vegetables     4    4930500.0        9861
# 40    HealthyKid 3+,Yummy Vegetables     5    4867500.0        9735
# 41    HealthyKid 3+,Yummy Vegetables     6    4861000.0        9722

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/juliarivera/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
ax = df_pivot.unstack(level=0).plot(kind='bar', subplots=True, rot=0, figsize=(20, 50), layout=(15, 1))
#plt.tight_layout()

# %%
df_g1 = df_2[['Total Sales','quantities']].groupby([df_2.transaction_items]).agg(sum)
df_g1 = df_g1.reset_index()

df_g1
# Out:
#                   transaction_items  Total Sales  quantities
# 0            Candy City,Gummy Worms    8897850.0       59319
# 1           Candy City,Orange Beans   11821794.0       59406
# 2      Exotic Extras,Beef Chicharon   77033298.0       59302
# 3  Exotic Extras,Kimchi and Seaweed   47452610.0       59390
# 4      HealthyKid 3+,Gummy Vitamins   89364000.0       59576
# 5      HealthyKid 3+,Nutrional Milk  116868720.0       58728
# 6    HealthyKid 3+,Yummy Vegetables   29714500.0       59429

# %%
y_pos = np.arange(len(df_g1['Total Sales']))

plt.bar(y_pos, df_g1['Total Sales'], align='center', alpha=0.5)
plt.xticks(y_pos,df_g1['transaction_items'])
plt.ylabel('Total Sales')
plt.title('Total Sales by Object Type')
plt.rcParams["figure.figsize"] = (50,50)
plt.rcParams.update({'font.size': 50})
plt.show()

# %%
y_pos = np.arange(len(df_g1['quantities']))

plt.bar(y_pos, df_g1['quantities'], align='center', alpha=0.5)
plt.xticks(y_pos,df_g1['transaction_items'])
plt.ylabel('Quantities')
plt.title('Quantities by Object Type')
plt.rcParams["figure.figsize"] = (50,50)
plt.rcParams.update({'font.size': 25})
plt.show()

# %%
df_g2 = df_2[['Total Sales','quantities']].groupby([df_2.Month]).agg(sum).reset_index()

y_pos = np.arange(len(df_g2['Total Sales']))

plt.bar(y_pos, df_g2['Total Sales'], align='center', alpha=0.5)
plt.xticks(y_pos,df_g2['Month'])
plt.ylabel('Total Sales')
plt.title('Total Sales by Month')
plt.rcParams["figure.figsize"] = (50,50)
plt.rcParams.update({'font.size': 50})
plt.show()

# %%
y_pos = np.arange(len(df_g2['quantities']))

plt.bar(y_pos, df_g2['quantities'], align='center', alpha=0.5)
plt.xticks(y_pos,df_g2['Month'])
plt.ylabel('Quantities')
plt.title('Quantity by Month')
plt.rcParams["figure.figsize"] = (50,50)
plt.rcParams.update({'font.size': 25})
plt.show()

# %%
df_2.pivot_table(index=["Month"], columns='transaction_items', values='Total Sales', aggfunc='sum').plot(kind='line',lw=5,fontsize=30).legend(loc='best',bbox_to_anchor=(1.0, 0.5))

# %%
df_g3 = df_2.pivot_table(index=["Month"], columns='transaction_items', values='quantities', aggfunc='sum')
df_g3.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df_cust = df_2[['name']].groupby([df_2.Month]).nunique()
df_cust = df_2[['name']].groupby([df_2.Month]).nunique()
df_cust_1 = df_2[['quantities']].groupby([df_2.name, df_2.Month]).agg(sum)
#df_cust_1 = df_cust_1.reset_index()
#df_cust_1 = df_cust_1.set_index("Month","name")
df_cust_1
new_index = pd.MultiIndex.from_product(df_cust_1.index.levels)
new_df = df_cust_1.reindex(new_index)
new_df = new_df.fillna(0).astype(int)

# %%
#new_df = new_df.reset_index()
#new_df = new_df.set_index("Month","name")
engaged = df_2[['name']].groupby([df_2.Month]).nunique()

new_df
# Out:
#                      quantities
# name          Month
# Aaron Beasley 1               0
#               2               0
#               3               0
#               4               9
#               5               8
# ...                         ...
# Zachary York  2              17
#               3               7
#               4              12
#               5              23
#               6               5
#
# [50922 rows x 1 columns]

# %%
new_df['Exists'] = new_df['quantities'].apply(lambda x: True if x >0 else False)

# %%
new_df_2 = new_df.unstack(['name'])
new_df_2 = new_df_2['Exists']
new_df_2.index = new_df_2.index.map(int)
new_df_2
# Out:
# name   Aaron Beasley  Aaron Brewer  Aaron Brown  Aaron Coffey  Aaron Davis  \
# Month
# 1              False          True        False          True         True
# 2              False          True        False          True         True
# 3              False          True         True          True        False
# 4               True          True         True          True         True
# 5               True         False         True          True         True
# 6               True          True         True         False         True
#
# name   Aaron Escobar  Aaron Flores  Aaron Flowers  Aaron Garrett  \
# Month
# 1              False          True           True           True
# 2               True          True           True           True
# 3              False          True          False           True
# 4               True          True           True          False
# 5               True         False          False           True
# 6              False          True           True           True
#
# name   Aaron Holder  ...  Zachary Richard  Zachary Salinas  Zachary Scott  \
# Month                ...
# 1             False  ...             True            False           True
# 2              True  ...             True             True           True
# 3              True  ...             True            False           True
# 4              True  ...             True             True           True
# 5              True  ...             True             True           True
# 6              True  ...             True             True           True
#
# name   Zachary Smith  Zachary Torres  Zachary Valentine  Zachary Ware  \
# Month
# 1               True           False               True          True
# 2               True           False               True          True
# 3               True            True               True          True
# 4               True            True               True          True
# 5               True            True               True          True
# 6               True            True               True          True
#
# name   Zachary Williams  Zachary Wilson  Zachary York
# Month
# 1                  True           False          True
# 2                  True           False          True
# 3                  True           False          True
# 4                  True            True          True
# 5                 False            True          True
# 6                 False            True          True
#
# [6 rows x 8487 columns]

# %%
new_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 1 to 6
# Columns: 8487 entries, Aaron Beasley to Zachary York
# dtypes: bool(8487)
# memory usage: 49.8 KB

# %%
repeaters = new_df_2.apply(lambda x: [0 if i==1 else (1 if x[i-1] and x[i] else 0)for i in x.index]).transpose().sum()
inactives = new_df_2.apply(lambda x: [0 if i==1 else ((1 if x[i]==0 else 0) if any(x[:i]) else 0) for i in x.index]).transpose().sum()
engaged = new_df_2.apply(lambda x: [1 if all(x[:i]) else 0 for i in x.index]).transpose().sum()

# %%
print(repeaters)
# Out:
# Month
# 1       0
# 2    5172
# 3    5216
# 4    5154
# 5    5110
# 6    5193
# dtype: int64

# %%
print(inactives)
# Out:
# Month
# 1       0
# 2    1416
# 3    1747
# 4    1909
# 5    1917
# 6    1835
# dtype: int64

# %%
print(engaged)
# Out:
# Month
# 1    6588
# 2    5172
# 3    4126
# 4    3289
# 5    2667
# 6    2190
# dtype: int64

# %%
table_for_customers = pd.DataFrame({
    'repeater': repeaters,
    'inactive': inactives,
    'engaged' : engaged
    })

table_for_customers=table_for_customers.transpose()

table_for_customers
# Out:
# Month        1     2     3     4     5     6
# repeater     0  5172  5216  5154  5110  5193
# inactive     0  1416  1747  1909  1917  1835
# engaged   6588  5172  4126  3289  2667  2190
